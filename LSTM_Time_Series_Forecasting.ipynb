# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("jena_climate_dataset.csv")
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
# Converting data to hourly timestamps
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 2009-01-01 19:00:00          0.44       2.32             3.73       1298.07
# 2009-01-01 20:00:00          0.45       2.36             3.78       1297.05
# 2009-01-01 21:00:00          0.42       2.40             3.85       1296.45
# 2009-01-01 22:00:00          0.42       2.46             3.95       1294.72
# 2009-01-01 23:00:00          0.43       2.46             3.95       1294.29
# 2009-01-02 00:00:00          0.30       2.53             4.06       1294.33
# 2009-01-02 01:00:00          0.25       2.58             4.15       1293.47
# 2009-01-02 02:00:00          0.24       2.62             4.20       1292.22
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 01:00:00      0.21           0.63     192.7
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 05:00:00      0.40           0.88     157.0
# 2009-01-01 06:00:00      0.05           0.50     146.0
# 2009-01-01 07:00:00      2.08           2.88     348.8
# 2009-01-01 08:00:00      0.72           1.25     213.9
# 2009-01-01 09:00:00      0.34           0.63     202.2
# 2009-01-01 10:00:00      1.45           3.00     292.6
# 2009-01-01 11:00:00      1.91           3.38     269.6
# 2009-01-01 12:00:00      1.84           2.63     184.4
# 2009-01-01 13:00:00      0.57           1.25     187.3
# 2009-01-01 14:00:00      1.25           2.00     144.0
# 2009-01-01 15:00:00      1.17           1.88     134.9
# 2009-01-01 16:00:00      1.40           2.13     145.5
# 2009-01-01 17:00:00      0.85           1.63     142.2
# 2009-01-01 18:00:00      0.55           1.00     183.7
# 2009-01-01 19:00:00      0.41           0.75     176.7
# 2009-01-01 20:00:00      0.68           1.13     195.2
# 2009-01-01 21:00:00      0.44           0.75     206.3
# 2009-01-01 22:00:00      0.33           0.63     175.7
# 2009-01-01 23:00:00      0.65           1.00     219.3
# 2009-01-02 00:00:00      0.41           0.88     155.0
# 2009-01-02 01:00:00      0.28           1.00     148.1
# 2009-01-02 02:00:00      0.49           0.88     209.8

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %% [markdown]
# ## Baseline Model - SeasonalNaive

# %%
from statsforecast import StatsForecast
from statsforecast.models import SeasonalNaive
from utilsforecast.plotting import plot_series

# %%
df_copy = df[['Date Time', 'T (degC)']].copy()

# %%
df_copy = df_copy.rename(columns={'Date Time': 'ds', 'T (degC)': 'y'})

# %%
df_copy['unique_id'] = 'series_1'

# %%
df_copy['ds'] = pd.to_datetime(df_copy['ds'], format='%d.%m.%Y %H:%M:%S')

# %%
df_copy_train = df_copy[:65000]

# %%
df_copy_actual = df_copy[65000:]

# %%
model = [SeasonalNaive(season_length=8760)] #last 1yr data

sf = StatsForecast(models=model, freq="H")
sf.fit(df=df_copy_train)
# Out:
# StatsForecast(models=[SeasonalNaive])

# %%
horizon = 5090
preds = sf.predict(h=horizon)
# Out:
# C:\Users\divya\.conda\envs\myenv\lib\site-packages\statsforecast\core.py:494: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
preds
# Out:
#                            ds  SeasonalNaive
# unique_id
# series_1  2016-05-30 19:00:00          20.00
# series_1  2016-05-30 20:00:00          19.18
# series_1  2016-05-30 21:00:00          18.13
# series_1  2016-05-30 22:00:00          17.82
# series_1  2016-05-30 23:00:00          17.11
# ...                       ...            ...
# series_1  2016-12-28 16:00:00           7.86
# series_1  2016-12-28 17:00:00           6.33
# series_1  2016-12-28 18:00:00           5.52
# series_1  2016-12-28 19:00:00           4.84
# series_1  2016-12-28 20:00:00           4.54
#
# [5090 rows x 2 columns]

# %%
preds = preds.reset_index()

# %%
df_copy_train
# Out:
#                                      ds      y unique_id
# Date Time
# 2009-01-01 01:00:00 2009-01-01 01:00:00  -8.05  series_1
# 2009-01-01 02:00:00 2009-01-01 02:00:00  -8.88  series_1
# 2009-01-01 03:00:00 2009-01-01 03:00:00  -8.81  series_1
# 2009-01-01 04:00:00 2009-01-01 04:00:00  -9.05  series_1
# 2009-01-01 05:00:00 2009-01-01 05:00:00  -9.63  series_1
# ...                                 ...    ...       ...
# 2016-05-30 14:00:00 2016-05-30 14:00:00  20.27  series_1
# 2016-05-30 15:00:00 2016-05-30 15:00:00  20.33  series_1
# 2016-05-30 16:00:00 2016-05-30 16:00:00  20.27  series_1
# 2016-05-30 17:00:00 2016-05-30 17:00:00  21.29  series_1
# 2016-05-30 18:00:00 2016-05-30 18:00:00  18.43  series_1
#
# [65000 rows x 3 columns]

# %%
df_copy_train = df_copy_train.reset_index(drop=True)
df_copy_train
# Out:
#                        ds      y unique_id
# 0     2009-01-01 01:00:00  -8.05  series_1
# 1     2009-01-01 02:00:00  -8.88  series_1
# 2     2009-01-01 03:00:00  -8.81  series_1
# 3     2009-01-01 04:00:00  -9.05  series_1
# 4     2009-01-01 05:00:00  -9.63  series_1
# ...                   ...    ...       ...
# 64995 2016-05-30 14:00:00  20.27  series_1
# 64996 2016-05-30 15:00:00  20.33  series_1
# 64997 2016-05-30 16:00:00  20.27  series_1
# 64998 2016-05-30 17:00:00  21.29  series_1
# 64999 2016-05-30 18:00:00  18.43  series_1
#
# [65000 rows x 3 columns]

# %%
plot_series(
    df=df_copy_train, 
    forecasts_df=preds,
    max_insample_length=14000, 
    palette="viridis")

# %% [markdown]
# - Evaluation

# %%
from sklearn.metrics import mean_absolute_error

# %%
eval_df = pd.merge(df_copy_actual, preds, 'left', ['ds', 'unique_id'])
eval_df = eval_df.dropna(axis=0)

# %%
MAE_Baseline = mean_absolute_error(eval_df['y'], eval_df['SeasonalNaive'])

# %%
MAE_Baseline
# Out:
# 4.8477962753950345

# %% [markdown]
# ## LSTM Model

# %% [markdown]
# - Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
dataset = temp.to_numpy().reshape(-1, 1)
train_size = 60000
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(dataset[:train_size])
scaled_dataset = scaler.transform(dataset)

# %% [markdown]
# - Sequencing the data

# %%
def df_to_X_y(df, window_size=5):
  df_as_np = df
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(scaled_dataset, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((70086, 5, 1, 1), (70086, 1))

# %% [markdown]
# - Splitting

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1, 1),
#  (60000, 1),
#  (5000, 5, 1, 1),
#  (5000, 1),
#  (5086, 5, 1, 1),
#  (5086, 1))

# %% [markdown]
# - Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17425 (68.07 KB)
# Trainable params: 17425 (68.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 0.0103 - root_mean_squared_error: 0.1014INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.0102 - root_mean_squared_error: 0.1012 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0343
# Epoch 2/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.0017 - root_mean_squared_error: 0.0412INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0017 - root_mean_squared_error: 0.0412 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 3/10
# 1864/1875 [============================>.] - ETA: 0s - loss: 0.0014 - root_mean_squared_error: 0.0378INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0014 - root_mean_squared_error: 0.0378 - val_loss: 7.8375e-04 - val_root_mean_squared_error: 0.0280
# Epoch 4/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 7.9602e-04 - root_mean_squared_error: 0.0282INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 6ms/step - loss: 7.9576e-04 - root_mean_squared_error: 0.0282 - val_loss: 3.3851e-04 - val_root_mean_squared_error: 0.0184
# Epoch 5/10
# 1863/1875 [============================>.] - ETA: 0s - loss: 3.8690e-04 - root_mean_squared_error: 0.0197INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 11s 6ms/step - loss: 3.8665e-04 - root_mean_squared_error: 0.0197 - val_loss: 2.7747e-04 - val_root_mean_squared_error: 0.0167
# Epoch 6/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 3.4776e-04 - root_mean_squared_error: 0.0186INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 11s 6ms/step - loss: 3.4719e-04 - root_mean_squared_error: 0.0186 - val_loss: 2.4683e-04 - val_root_mean_squared_error: 0.0157
# Epoch 7/10
# 1875/1875 [==============================] - ETA: 0s - loss: 3.1829e-04 - root_mean_squared_error: 0.0178INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 6ms/step - loss: 3.1829e-04 - root_mean_squared_error: 0.0178 - val_loss: 2.1876e-04 - val_root_mean_squared_error: 0.0148
# Epoch 8/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 2.9219e-04 - root_mean_squared_error: 0.0171INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 6ms/step - loss: 2.9199e-04 - root_mean_squared_error: 0.0171 - val_loss: 2.0842e-04 - val_root_mean_squared_error: 0.0144
# Epoch 9/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 2.6644e-04 - root_mean_squared_error: 0.0163INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 11s 6ms/step - loss: 2.6615e-04 - root_mean_squared_error: 0.0163 - val_loss: 1.8969e-04 - val_root_mean_squared_error: 0.0138
# Epoch 10/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 2.4575e-04 - root_mean_squared_error: 0.0157INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 6ms/step - loss: 2.4571e-04 - root_mean_squared_error: 0.0157 - val_loss: 1.8703e-04 - val_root_mean_squared_error: 0.0137

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %% [markdown]
# - Predictions on train and val data

# %%
scaledtrain_predictions = model1.predict(X_train1)
train_predictions = scaler.inverse_transform(scaledtrain_predictions)
y_train1 = scaler.inverse_transform(y_train1.reshape(-1, 1))
# Out:
# 1875/1875 [==============================] - 5s 2ms/step

# %%
train_results = pd.DataFrame(data={'Train Predictions':train_predictions.flatten(), 'Actuals':y_train1.flatten()})
train_results
# Out:
#        Train Predictions  Actuals
# 0              -9.385587    -9.67
# 1              -9.511493    -9.17
# 2              -9.084736    -8.10
# 3              -7.986335    -7.66
# 4              -7.298061    -7.04
# ...                  ...      ...
# 59995           5.303595     6.07
# 59996           7.036416     9.88
# 59997          10.994532    13.53
# 59998          15.284918    15.43
# 59999          17.502211    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
scaledval_predictions = model1.predict(X_val1)
val_predictions = scaler.inverse_transform(scaledval_predictions)
y_val1 = scaler.inverse_transform(y_val1.reshape(-1, 1))
# Out:
# 157/157 [==============================] - 1s 2ms/step

# %%
val_results = pd.DataFrame(data={'Val Predictions':val_predictions.flatten(), 'Actuals':y_val1.flatten()})
val_results
# Out:
#       Val Predictions  Actuals
# 0           17.223141    14.02
# 1           14.665782    13.67
# 2           13.496110    12.27
# 3           11.834791    11.19
# 4           10.639543    10.85
# ...               ...      ...
# 4995        18.183983    18.27
# 4996        17.576307    17.85
# 4997        17.225874    16.65
# 4998        16.084217    15.85
# 4999        15.299988    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %% [markdown]
# - Test Predictions

# %%
scaledtest_predictions = model1.predict(X_test1)
test_predictions = scaler.inverse_transform(scaledtest_predictions)
y_test1 = scaler.inverse_transform(y_test1.reshape(-1, 1))
# Out:
# 159/159 [==============================] - 0s 2ms/step

# %%
test_results = pd.DataFrame(data={'Test Predictions':test_predictions.flatten(), 'Actuals':y_test1.flatten()})
test_results
# Out:
#       Test Predictions  Actuals
# 0            14.515825    13.99
# 1            13.441085    13.46
# 2            12.957768    12.93
# 3            12.553783    12.43
# 4            12.162991    12.17
# ...                ...      ...
# 5081         -0.671339    -0.98
# 5082         -1.347547    -1.40
# 5083         -1.514230    -2.75
# 5084         -2.662439    -2.89
# 5085         -2.889517    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %% [markdown]
# - Evaluation

# %%
MAE_LSTM = mean_absolute_error(test_results['Test Predictions'],test_results['Actuals'])

# %%
MAE_LSTM
# Out:
# 0.6295712255728417
